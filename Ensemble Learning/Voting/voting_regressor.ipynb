# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_openml

X,y = fetch_openml(name="boston", version=1, return_X_y=True)

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
X
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
svr = SVR()

# %%
estimators = [('lr',lr),('dt',dt),('svr',svr)]

# %%
for estimator in estimators:
  scores = cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
  print(estimator[0],np.round(np.mean(scores),2))
# Out:
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# lr nan
# dt -0.17
# svr -0.41

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
# Out:
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# Voting Regressor nan
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(

# %%
for i in range(1,4):
  for j in range(1,4):
    for k in range(1,4):
      vr = VotingRegressor(estimators,weights=[i,j,k])
      scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
      print("For i={},j={},k={}".format(i,j,k),np.round(np.mean(scores),2))
# Out:
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# For i=1,j=1,k=1 nan
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# For i=1,j=1,k=2 nan
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
# ...
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# For i=3,j=3,k=2 nan
# For i=3,j=3,k=3 nan
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\model_selection\_validation.py:971: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 152, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 400, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 298, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Study\Machine Learning\Learning ML\venv\Lib\site-packages\sklearn\linear_model\_base.py", line 280, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(

# %%
# using the same algorithm

dt1 = DecisionTreeRegressor(max_depth=1)
dt2 = DecisionTreeRegressor(max_depth=3)
dt3 = DecisionTreeRegressor(max_depth=5)
dt4 = DecisionTreeRegressor(max_depth=7)
dt5 = DecisionTreeRegressor(max_depth=None)

# %%
estimators = [('dt1',dt1),('dt2',dt2),('dt3',dt3),('dt4',dt4),('dt5',dt5)]

# %%
for estimator in estimators:
  scores = cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
  print(estimator[0],np.round(np.mean(scores),2))
# Out:
# dt1 -0.85
# dt2 -0.11
# dt3 0.07
# dt4 -0.02
# dt5 -0.07

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
# Out:
# Voting Regressor 0.17
